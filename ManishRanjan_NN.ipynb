# %% [markdown]
# <div class="alert alert-info">
#     <font style="font-size:15px">
#     <strong>Problem statement:</strong> To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution that can evaluate images and alert dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.
#
# <strong>Project Pipeline</strong>
# <ul>
#     <li>Data Reading/Data Understanding</li>
#     <li>Dataset Creation</li>
#     <li>Dataset visualisation </li>
#     <li>Model Building & training</li>
#     <li>Chose an appropriate data augmentation strategy to resolve underfitting/overfitting </li>
#     <li>Model Building & training on the augmented data </li>
#     <li>Class distribution</li>
#     <li>Handling class imbalances </li>
#     <li>Model Building & training on the rectified class imbalance data</li>
# </ul>
#     </font>
# </div>

# %% [markdown]
# ### Importing Skin Cancer Data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL as pl
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

from glob import glob
from tensorflow.keras.preprocessing import image_dataset_from_directory

# %%
# I have extracted CNN_assignment.zip in a folder named CNN_assignment on my Google Drive. 
# Mounting the google drive here
from google.colab import drive
drive.mount('/content/gdrive')


##Ref:https://towardsdatascience.com/downloading-datasets-into-google-drive-via-google-colab-bcb1b30b0166
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Check folders 
# !ls gdrive/MyDrive/CNN_assignment
print("Train Folder")
# !ls gdrive/MyDrive/CNN_assignment/Train/
print("Test Folder")
# !ls gdrive/MyDrive/CNN_assignment/Test/
# Out:
# Test  Train
# Train Folder
# 'actinic keratosis'	 melanoma		      'seborrheic keratosis'
# 'basal cell carcinoma'	 nevus			      'squamous cell carcinoma'
#  dermatofibroma		'pigmented benign keratosis'  'vascular lesion'
# Test Folder
# 'actinic keratosis'	 melanoma		      'seborrheic keratosis'
# 'basal cell carcinoma'	 nevus			      'squamous cell carcinoma'
#  dermatofibroma		'pigmented benign keratosis'  'vascular lesion'

# %%
# Defining the path for train and test images
# We get Train and Test folders in the extracted folder "Skin cancer ISIC The International Skin Imaging Collaboration"
train_path="gdrive/MyDrive/CNN_assignment/Train"
test_path="gdrive/MyDrive/CNN_assignment/Test"
data_dir_train = pathlib.Path(train_path)
data_dir_test = pathlib.Path(test_path)

# %%
# Delete output folder if created during augumentenation in any previous model building.
# import shell utility
import shutil

for folder in os.listdir(train_path):
  output_path = train_path + '/' + folder + '/output'
  if os.path.exists(output_path):
    shutil.rmtree(output_path)

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print("Images in Train folder", image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print("Images in Test folder",image_count_test)
# Out:
# Images in Train folder 2239
# Images in Test folder 118

# %% [markdown]
# <div class="alert alert-info">
# <strong>Observations:</strong>
#
# This assignment uses a dataset of 2357 images of skin cancer types. The dataset contains 9 sub-folders in each train and test subdirectories. The 9 sub-folders contains the images of 9 skin cancer types respectively.
#
# Train sub-folder contains 2239 images and Test sub-folder contains 118 images
# </div>

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write train dataset here
## use seed=123 while creating the dataset
## resize the images to the size img_height*img_width, while writting the dataset
train_ds = image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Write validation dataset here
## use seed=123 while creating the dataset
## resize the images to the size img_height*img_width, while writting the dataset
val_ds = image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list. 
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data

# %%
#### Create a code to visualize one instance of all the nine classes present in the training or validation dataset

plt.figure(figsize=(12, 12))
for images, labels in train_ds.take(1): # using training dataset
  # run it for each class
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (32, 180, 180, 3)
# (32,)

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %% [markdown]
# #### Model 1 - Default Vanilla

# %%
num_classes = 9

# Build Normalization layer by rescaling between 0-1, lets also specify input shape with 180x180x3 as we will be using this in all future layers
normalization_layer = layers.experimental.preprocessing.Rescaling(1./255,input_shape=(img_height, img_width, 3))

# Build sequential model with 3 conv layers with 16, 32 and 64 filters, 3 max pooling, flatten the layer,  build a dense layer of 128 and conclude with softmax function layer
model = Sequential([
  normalization_layer,
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes,activation='softmax')
])

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### using 'adam' optimizer
### Using SparseCategoricalCrossentropy loss function as there are 9 categories and it uses a single integer for a class, rather than a whole vector. 
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 128)               3965056
#
#  dense_1 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 3,989,801
# Trainable params: 3,989,801
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
# train the model for 20 epochs
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 56/56 [==============================] - 16s 69ms/step - loss: 2.0627 - accuracy: 0.2539 - val_loss: 1.7785 - val_accuracy: 0.3490
# Epoch 2/20
# 56/56 [==============================] - 1s 16ms/step - loss: 1.6278 - accuracy: 0.4291 - val_loss: 1.4607 - val_accuracy: 0.5101
# Epoch 3/20
# 56/56 [==============================] - 1s 16ms/step - loss: 1.3964 - accuracy: 0.5151 - val_loss: 1.4147 - val_accuracy: 0.5324
# Epoch 4/20
# 56/56 [==============================] - 1s 16ms/step - loss: 1.3016 - accuracy: 0.5435 - val_loss: 1.3618 - val_accuracy: 0.5615
# Epoch 5/20
# 56/56 [==============================] - 1s 16ms/step - loss: 1.2186 - accuracy: 0.5792 - val_loss: 1.3825 - val_accuracy: 0.5324
# Epoch 6/20
# 56/56 [==============================] - 1s 16ms/step - loss: 1.1608 - accuracy: 0.5804 - val_loss: 1.3614 - val_accuracy: 0.5347
# Epoch 7/20
# 56/56 [==============================] - 1s 16ms/step - loss: 1.0709 - accuracy: 0.6205 - val_loss: 1.4536 - val_accuracy: 0.5459
# Epoch 8/20
# 56/56 [==============================] - 1s 16ms/step - loss: 0.9950 - accuracy: 0.6445 - val_loss: 1.4697 - val_accuracy: 0.5660
# Epoch 9/20
# 56/56 [==============================] - 1s 16ms/step - loss: 0.9116 - accuracy: 0.6730 - val_loss: 1.6031 - val_accuracy: 0.5213
# Epoch 10/20
# 56/56 [==============================] - 1s 16ms/step - loss: 0.8056 - accuracy: 0.7093 - val_loss: 1.6720 - val_accuracy: 0.5548
# Epoch 11/20
# 56/56 [==============================] - 1s 16ms/step - loss: 0.7195 - accuracy: 0.7411 - val_loss: 1.7894 - val_accuracy: 0.4877
# Epoch 12/20
# 56/56 [==============================] - 1s 16ms/step - loss: 0.6802 - accuracy: 0.7528 - val_loss: 1.7433 - val_accuracy: 0.5414
# Epoch 13/20
# 56/56 [==============================] - 1s 16ms/step - loss: 0.6056 - accuracy: 0.7801 - val_loss: 1.8311 - val_accuracy: 0.5324
# Epoch 14/20
# 56/56 [==============================] - 1s 16ms/step - loss: 0.5044 - accuracy: 0.8158 - val_loss: 1.9166 - val_accuracy: 0.5369
# Epoch 15/20
# 56/56 [==============================] - 1s 16ms/step - loss: 0.5039 - accuracy: 0.8237 - val_loss: 1.9102 - val_accuracy: 0.5436
# Epoch 16/20
# 56/56 [==============================] - 1s 16ms/step - loss: 0.4674 - accuracy: 0.8304 - val_loss: 1.9005 - val_accuracy: 0.5347
# Epoch 17/20
# 56/56 [==============================] - 1s 16ms/step - loss: 0.3466 - accuracy: 0.8722 - val_loss: 2.2593 - val_accuracy: 0.5101
# Epoch 18/20
# 56/56 [==============================] - 1s 16ms/step - loss: 0.3387 - accuracy: 0.8767 - val_loss: 2.5949 - val_accuracy: 0.4765
# Epoch 19/20
# 56/56 [==============================] - 1s 16ms/step - loss: 0.3286 - accuracy: 0.8823 - val_loss: 2.2808 - val_accuracy: 0.5481
# Epoch 20/20
# 56/56 [==============================] - 1s 16ms/step - loss: 0.2895 - accuracy: 0.8878 - val_loss: 2.4364 - val_accuracy: 0.5302

# %% [markdown]
# ### Visualizing training results

# %%
# Generic Function to visualize the accuracy, we will use this for differnet models
def accuracy_plot(history, epochs):
  acc = history.history['accuracy']
  val_acc = history.history['val_accuracy']

  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs_range = range(epochs)

  plt.figure(figsize=(8, 8))
  plt.subplot(1, 2, 1)
  plt.plot(epochs_range, acc, label='Training Accuracy')
  plt.plot(epochs_range, val_acc, label='Validation Accuracy')
  plt.legend(loc='lower right')
  plt.title('Training and Validation Accuracy')

  plt.subplot(1, 2, 2)
  plt.plot(epochs_range, loss, label='Training Loss')
  plt.plot(epochs_range, val_loss, label='Validation Loss')
  plt.legend(loc='upper right')
  plt.title('Training and Validation Loss')
  plt.show()

# %%
# Visualize this model
accuracy_plot(history, epochs)

# %%
# Lets store the final accuracy in a dataframe for the consecutive training
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
accuracy_history_df = pd.DataFrame(data=[{"Type":"Model 1 - Default Vanilla","Training Accuracy":acc[-1],"Validation Accuracy":val_acc[-1],"Training Loss":loss[-1],"Validation Loss":val_loss[-1],"Epochs":epochs}])
accuracy_history_df
# Out:
#                         Type  Training Accuracy  Validation Accuracy  \
# 0  Model 1 - Default Vanilla           0.887835             0.530201
#
#    Training Loss  Validation Loss  Epochs
# 0       0.289494         2.436409      20

# %% [markdown]
# <div class="alert alert-info">
# <strong>Observations:</strong>
# <ul>
# <li>Big difference observed between Training and Validation accuracy.</li>
# <li>The validation loss as observed is very high. We can also see that training loss decreased and validation loss increased with the number of epochs. </li>
# <li>We can see from the plot that as the number of epochs increases, the training accuracy also increased but the validation accuracy reduced. This is a clear case of <strong>overfitting</strong>.</li>
# <li>We should add some Dropout layers and add some data augumentation strategy.</li>
# <li>By adding a few more layers, we could improve the accuracy by trying to extract more features.</li>
# </ul>
# </div>

# %%
# Selecting an appropriate data augumentation strategy. 

data_augmentation = keras.Sequential([
                             layers.experimental.preprocessing.RandomFlip(mode="horizontal_and_vertical",input_shape=(img_height,img_width,3)),
                             layers.experimental.preprocessing.RandomRotation(0.1, fill_mode='reflect'),
                             layers.experimental.preprocessing.RandomZoom(0.1)
])

# %%
# Visualize how the above augmentation strategy works for one instance of training image.

plt.figure(figsize=(12, 12))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(data_augmentation(images)[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# ### Model 2 - Extra data augmentation layer

# %%
# Build the sequential layers same as before with an extra data augmentation layer
# Using a dropout layer as well 
model = Sequential([
  # layers.experimental.preprocessing.Rescaling(1./255, offset=0.0),
  normalization_layer,
  data_augmentation,
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes,activation='softmax')
])

# %% [markdown]
# ### Compiling the model

# %%
### using 'adam' optimizer
### Using SparseCategoricalCrossentropy loss function as there are 9 categories and it uses a single integer for a class, rather than a whole vector. 
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Training the model

# %%
## train the model for 20 epochs
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 56/56 [==============================] - 3s 29ms/step - loss: 2.0807 - accuracy: 0.2455 - val_loss: 1.8227 - val_accuracy: 0.3221
# Epoch 2/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.7218 - accuracy: 0.3906 - val_loss: 1.6300 - val_accuracy: 0.4340
# Epoch 3/20
# 56/56 [==============================] - 1s 20ms/step - loss: 1.5331 - accuracy: 0.4643 - val_loss: 1.4976 - val_accuracy: 0.5034
# Epoch 4/20
# 56/56 [==============================] - 1s 20ms/step - loss: 1.4067 - accuracy: 0.5173 - val_loss: 1.3997 - val_accuracy: 0.5257
# Epoch 5/20
# 56/56 [==============================] - 1s 20ms/step - loss: 1.3631 - accuracy: 0.5140 - val_loss: 1.3662 - val_accuracy: 0.5302
# Epoch 6/20
# 56/56 [==============================] - 1s 20ms/step - loss: 1.3988 - accuracy: 0.5100 - val_loss: 1.3887 - val_accuracy: 0.5280
# Epoch 7/20
# 56/56 [==============================] - 1s 20ms/step - loss: 1.2985 - accuracy: 0.5307 - val_loss: 1.4480 - val_accuracy: 0.5123
# Epoch 8/20
# 56/56 [==============================] - 1s 20ms/step - loss: 1.3216 - accuracy: 0.5374 - val_loss: 1.4425 - val_accuracy: 0.5101
# Epoch 9/20
# 56/56 [==============================] - 1s 20ms/step - loss: 1.3176 - accuracy: 0.5329 - val_loss: 1.4591 - val_accuracy: 0.4944
# Epoch 10/20
# 56/56 [==============================] - 1s 20ms/step - loss: 1.2798 - accuracy: 0.5508 - val_loss: 1.3597 - val_accuracy: 0.5123
# Epoch 11/20
# 56/56 [==============================] - 1s 20ms/step - loss: 1.2485 - accuracy: 0.5597 - val_loss: 1.3981 - val_accuracy: 0.5168
# Epoch 12/20
# 56/56 [==============================] - 1s 20ms/step - loss: 1.2841 - accuracy: 0.5407 - val_loss: 1.3095 - val_accuracy: 0.5414
# Epoch 13/20
# 56/56 [==============================] - 1s 20ms/step - loss: 1.2146 - accuracy: 0.5714 - val_loss: 1.2830 - val_accuracy: 0.5705
# Epoch 14/20
# 56/56 [==============================] - 1s 20ms/step - loss: 1.2088 - accuracy: 0.5658 - val_loss: 1.4216 - val_accuracy: 0.4922
# Epoch 15/20
# 56/56 [==============================] - 1s 20ms/step - loss: 1.2254 - accuracy: 0.5536 - val_loss: 1.3960 - val_accuracy: 0.5503
# Epoch 16/20
# 56/56 [==============================] - 1s 19ms/step - loss: 1.1831 - accuracy: 0.5709 - val_loss: 1.3929 - val_accuracy: 0.5615
# Epoch 17/20
# 56/56 [==============================] - 1s 20ms/step - loss: 1.1855 - accuracy: 0.5748 - val_loss: 1.3220 - val_accuracy: 0.5638
# Epoch 18/20
# 56/56 [==============================] - 1s 20ms/step - loss: 1.1399 - accuracy: 0.5938 - val_loss: 1.3373 - val_accuracy: 0.5302
# Epoch 19/20
# 56/56 [==============================] - 1s 20ms/step - loss: 1.1322 - accuracy: 0.5859 - val_loss: 1.3590 - val_accuracy: 0.5481
# Epoch 20/20
# 56/56 [==============================] - 1s 20ms/step - loss: 1.1396 - accuracy: 0.5926 - val_loss: 1.3337 - val_accuracy: 0.5593

# %% [markdown]
# ### Visualizing the results

# %%
# Visualize this model
accuracy_plot(history, epochs)

# %%
# Lets store the final accuracy of model 2 in accuracy_history_df dataframe
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
accuracy_history_df = accuracy_history_df.append([{"Type":"Model 2 - Extra data augmentation layer","Training Accuracy":acc[-1],"Validation Accuracy":val_acc[-1],"Training Loss":loss[-1],"Validation Loss":val_loss[-1],"Epochs":epochs}])
accuracy_history_df
# Out:
#                                       Type  Training Accuracy  \
# 0                Model 1 - Default Vanilla           0.887835
# 0  Model 2 - Extra data augmentation layer           0.592634
#
#    Validation Accuracy  Training Loss  Validation Loss  Epochs
# 0             0.530201       0.289494         2.436409      20
# 0             0.559284       1.139552         1.333660      20

# %% [markdown]
# <div class="alert alert-info">
# <strong>Observations:</strong>
# <ul>
# <li>This is a much better model compared to the previous one. Difference between Training and Validation accuracy has reduced significantly.</li>
# <li>Difference between Training and Vaidation loss is not that big now.</li>
# <li>Training accuracy is low which indicates <strong>underfitting</strong>.</li>
# </ul>
# </div>

# %% [markdown]
# #### Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
# taking the complete training dtaa folder as source dataset
source_ds = image_dataset_from_directory(
  data_dir_train
)
# Initialize an emtpy dict
class_distr={}
# Go through all training dataset batches
for image_batch, labels_batch in source_ds:
  # prepare the count of images in each class
    for i in range(image_batch.shape[0]):
      if class_names[labels_batch[i]] in class_distr:
        class_distr[class_names[labels_batch[i]]]+=1
      else:
        class_distr[class_names[labels_batch[i]]]=1
# Display the distribution
class_distr
# Out:
# Found 2239 files belonging to 9 classes.
# {'pigmented benign keratosis': 462,
#  'melanoma': 438,
#  'squamous cell carcinoma': 181,
#  'dermatofibroma': 95,
#  'nevus': 357,
#  'basal cell carcinoma': 376,
#  'actinic keratosis': 114,
#  'seborrheic keratosis': 77,
#  'vascular lesion': 139}

# %%
# Prepare a class distribution Dataframe using the dictionary class_distr
df_sample_distr = pd.DataFrame({"Class Name":class_distr.keys(), "Samples":class_distr.values()})
df_sample_distr.sort_values('Samples',ascending=False)
# Out:
#                    Class Name  Samples
# 0  pigmented benign keratosis      462
# 1                    melanoma      438
# 5        basal cell carcinoma      376
# 4                       nevus      357
# 2     squamous cell carcinoma      181
# 8             vascular lesion      139
# 6           actinic keratosis      114
# 3              dermatofibroma       95
# 7        seborrheic keratosis       77

# %%
# Visualize Class Distribution
import seaborn as sns
plt.figure(figsize=(10, 10))
sns.barplot(data=df_sample_distr,x='Class Name',y='Samples')
plt.xticks(rotation = 45) 
plt.show()

# %% [markdown]
# <div class="alert alert-info">
# <strong>Observations:</strong>
# <ul>
# <li>Class imbalance found in the training dataset</li>
# <li>Class <strong>pigmented benign keratosis</strong> has maximum number of samples (462, 20.63%).</li>
# <li>Class <strong>seborrheic keratosis</strong> has least number of samples.</li>
# </ul>
# </div>

# %% [markdown]
# #### Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied:
jpg',
#  'gdrive/MyDrive/CNN_assignment/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0028168.jpg_a5b2a0e2-2c55-466e-a0e7-569f6b7a39e5.jpg',
#  'gdrive/MyDrive/CNN_assignment/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0031413.jpg_57d0392b-42ad-44e2-8c84-5f9e5b9de9dc.jpg',
#  'gdrive/MyDrive/CNN_assignment/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0029230.jpg_c67e6431-02ac-4bab-b06f-16308e3be097.jpg',
#  'gdrive/MyDrive/CNN_assignment/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0027629.jpg_0e20f41a-de16-481e-a2bf-24819dd78cac.jpg',
#  'gdrive/MyDrive/CNN_assignment/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0026574.jpg_88d952af-4798-4d11-9084-8263b9bdfe79.jpg',
#  'gdrive/MyDrive/CNN_assignment/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0025650.jpg_f3fa4f6c-55a4-4b46-aa8f-bb2d42ef0d16.jpg',
#  'gdrive/MyDrive/CNN_assignment/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0025971.jpg_efddd7a6-38fc-41fc-b974-50629508eb1d.jpg',
#  'gdrive/MyDrive/CNN_assignment/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0025383.jpg_423a282c-2cca-4821-becb-9f5b375d15a8.jpg',
#  'gdrive/MyDrive/CNN_assignment/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0024595.jpg_c1f3f887-69d8-4b99-9824-848ce467959e.jpg',
#  'gdrive/MyDrive/CNN_assignment/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0030746.jpg_5e156468-4aa7-4498-b1df-405ed8caccfd.jpg',
#  'gdrive/MyDrive/CNN_assignment/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0027744.jpg_63b30c5e-9081-4d69-94b1-43a83a333693.jpg',
#  'gdrive/MyDrive/CNN_assignment/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0031122.jpg_6547a55d-9205-4515-af7d-86853da12544.jpg',
#  'gdrive/MyDrive/CNN_assignment/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0025144.jpg_ed437877-97ef-4e98-87f5-b014b618f35e.jpg',
#  'gdrive/MyDrive/CNN_assignment/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0030766.jpg_56c0aec3-9a27-402b-a404-668f3033b54d.jpg',
#  'gdrive/MyDrive/CNN_assignment/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0031539.jpg_41e8ad70-a1cb-490d-9e10-894eb466acea.jpg',
#  'gdrive/MyDrive/CNN_assignment/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0027371.jpg_fd54b1dd-65e1-4b8b-91f6-28f4ea614bd6.jpg',
#  'gdrive/MyDrive/CNN_assignment/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0028283.jpg_e2756866-a31b-46d1-81ba-d8ff0535ba9c.jpg',
#  'gdrive/MyDrive/CNN_assignment/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0030261.jpg_c3abedf2-687b-428a-92f8-63b5eb97fdf1.jpg',
#  'gdrive/MyDrive/CNN_assignment/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0031384.jpg_0f5a228b-0e9f-4903-85dc-fa755e936ef6.jpg',
#  'gdrive/MyDrive/CNN_assignment/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0026902.jpg_f3df84c1-2a09-489e-83c3-39f1de7d951c.jpg',
#  'gdrive/MyDrive/CNN_assignment/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0030800.jpg_be723c5e-b735-4f30-bba8-5314a9121054.jpg',
#  'gdrive/MyDrive/CNN_assignment/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0029524.jpg_d65c6035-be43-4262-891d-8d843b02412e.jpg',
#  'gdrive/MyDrive/CNN_assignment/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0024795.jpg_ed84b4dd-5fd3-4566-980f-be259104a73c.jpg',
#  'gdrive/MyDrive/CNN_assignment/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0025433.jpg_b9a3cd61-f32b-4183-9e3b-0fdcb5ec707e.jpg',
#  'gdrive/MyDrive/CNN_assignment/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0027146.jpg_a3dc81ef-fafc-4e02-bb9a-b3a89353bcf9.jpg',
#  'gdrive/MyDrive/CNN_assignment/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0024885.jpg_cc557bdd-71d8-4c5d-956a-e5c7272b9bbe.jpg',
#  'gdrive/MyDrive/CNN_assignment/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0030096.jpg_f9b1f3e2-4b6c-4ee5-a5b6-0aca2c5d4964.jpg',
#  ...]

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
lesion_list_new
# Out:
# ['actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  ...]

# %%
# Check the class balance after agumentation
path_list_orig = [x for x in glob(os.path.join(data_dir_train, '*', '*.jpg'))]
lesion_list_orig = [os.path.basename(os.path.dirname(y)) for y in glob(os.path.join(data_dir_train, '*', '*.jpg'))]
dataframe_dict_original = dict(zip(path_list_orig, lesion_list_orig))
original_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])

dataframe_dict_new = dict(zip(path_list_new, lesion_list_new))

dataframe_new = original_df.append(pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label']))

dataframe_new['Label'].value_counts()
# Out:
# pigmented benign keratosis    962
# melanoma                      938
# basal cell carcinoma          876
# nevus                         857
# squamous cell carcinoma       681
# vascular lesion               639
# actinic keratosis             614
# dermatofibroma                595
# seborrheic keratosis          577
# Name: Label, dtype: int64

# %% [markdown]
# 500 images added to all the classes to maintain class balance. More images can be added to improve training process.

# %% [markdown]
# #### Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### Create a training dataset

# %%
train_ds = image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training', ## choose the correct parameter value, so that only training data is refered to
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# #### Create a validation dataset

# %%
val_ds = image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',## choose the correct parameter value, so that only validation data is refered to,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %% [markdown]
# #### Model 3 - Class rebalance

# %%
## Handle class imbalance in this model
AUTOTUNE = tf.data.experimental.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

model = Sequential([
  # layers.experimental.preprocessing.Rescaling(1./255),
  normalization_layer,
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# #### Compile your model (Choose optimizer and loss function appropriately)

# %%
## Compile the model
### using 'adam' optimizer
### Using SparseCategoricalCrossentropy loss function as there are 9 categories and it uses a single integer for a class, rather than a whole vector. 
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# #### Train your model

# %%
## train the model for 50 epochs.
epochs = 50
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/50
# 169/169 [==============================] - 40s 50ms/step - loss: 1.8275 - accuracy: 0.3134 - val_loss: 1.4168 - val_accuracy: 0.4796
# Epoch 2/50
# 169/169 [==============================] - 3s 16ms/step - loss: 1.3643 - accuracy: 0.4998 - val_loss: 1.2478 - val_accuracy: 0.5776
# Epoch 3/50
# 169/169 [==============================] - 3s 16ms/step - loss: 1.1096 - accuracy: 0.5979 - val_loss: 1.0863 - val_accuracy: 0.5880
# Epoch 4/50
# 169/169 [==============================] - 3s 16ms/step - loss: 0.9619 - accuracy: 0.6534 - val_loss: 1.0156 - val_accuracy: 0.6488
# Epoch 5/50
# 169/169 [==============================] - 3s 16ms/step - loss: 0.8047 - accuracy: 0.7092 - val_loss: 0.8610 - val_accuracy: 0.7030
# Epoch 6/50
# 169/169 [==============================] - 3s 16ms/step - loss: 0.6461 - accuracy: 0.7617 - val_loss: 0.8409 - val_accuracy: 0.7305
# Epoch 7/50
# 169/169 [==============================] - 3s 16ms/step - loss: 0.5354 - accuracy: 0.8073 - val_loss: 0.7719 - val_accuracy: 0.7506
# Epoch 8/50
# 169/169 [==============================] - 3s 16ms/step - loss: 0.4228 - accuracy: 0.8479 - val_loss: 0.8208 - val_accuracy: 0.7550
# Epoch 9/50
# 169/169 [==============================] - 3s 16ms/step - loss: 0.3893 - accuracy: 0.8650 - val_loss: 0.7597 - val_accuracy: 0.7736
# Epoch 10/50
# 169/169 [==============================] - 3s 16ms/step - loss: 0.2905 - accuracy: 0.8974 - val_loss: 0.6850 - val_accuracy: 0.8003
# Epoch 11/50
# 169/169 [==============================] - 3s 16ms/step - loss: 0.2814 - accuracy: 0.8989 - val_loss: 0.7989 - val_accuracy: 0.7632
# Epoch 12/50
# 169/169 [==============================] - 3s 16ms/step - loss: 0.2345 - accuracy: 0.9154 - val_loss: 0.7023 - val_accuracy: 0.7988
# Epoch 13/50
# 169/169 [==============================] - 3s 16ms/step - loss: 0.2152 - accuracy: 0.9227 - val_loss: 0.8077 - val_accuracy: 0.7877
# Epoch 14/50
# 169/169 [==============================] - 3s 16ms/step - loss: 0.2100 - accuracy: 0.9206 - val_loss: 0.7090 - val_accuracy: 0.7996
# Epoch 15/50
# 169/169 [==============================] - 3s 18ms/step - loss: 0.1715 - accuracy: 0.9355 - val_loss: 0.6465 - val_accuracy: 0.8315
# Epoch 16/50
# 169/169 [==============================] - 3s 16ms/step - loss: 0.1493 - accuracy: 0.9410 - val_loss: 0.7484 - val_accuracy: 0.8129
# Epoch 17/50
# 169/169 [==============================] - 3s 16ms/step - loss: 0.1683 - accuracy: 0.9366 - val_loss: 0.7593 - val_accuracy: 0.7884
# Epoch 18/50
# 169/169 [==============================] - 3s 16ms/step - loss: 0.2144 - accuracy: 0.9201 - val_loss: 0.8046 - val_accuracy: 0.7973
# Epoch 39/50
# 169/169 [==============================] - 3s 16ms/step - loss: 0.0960 - accuracy: 0.9579 - val_loss: 0.8100 - val_accuracy: 0.8285
# Epoch 40/50
# 169/169 [==============================] - 3s 16ms/step - loss: 0.0852 - accuracy: 0.9596 - val_loss: 0.8367 - val_accuracy: 0.8396
# Epoch 41/50
# 169/169 [==============================] - 3s 16ms/step - loss: 0.0986 - accuracy: 0.9564 - val_loss: 0.9924 - val_accuracy: 0.8241
# Epoch 42/50
# 169/169 [==============================] - 3s 16ms/step - loss: 0.2432 - accuracy: 0.9223 - val_loss: 1.1710 - val_accuracy: 0.7847
# Epoch 43/50
# 169/169 [==============================] - 3s 16ms/step - loss: 0.1257 - accuracy: 0.9483 - val_loss: 0.9160 - val_accuracy: 0.8330
# Epoch 44/50
# 169/169 [==============================] - 3s 16ms/step - loss: 0.0924 - accuracy: 0.9579 - val_loss: 0.8431 - val_accuracy: 0.8382
# Epoch 45/50
# 169/169 [==============================] - 3s 16ms/step - loss: 0.0817 - accuracy: 0.9633 - val_loss: 1.0166 - val_accuracy: 0.8233
# Epoch 46/50
# 169/169 [==============================] - 3s 16ms/step - loss: 0.1120 - accuracy: 0.9542 - val_loss: 0.9574 - val_accuracy: 0.7780
# Epoch 47/50
# 169/169 [==============================] - 3s 16ms/step - loss: 0.0903 - accuracy: 0.9609 - val_loss: 0.8560 - val_accuracy: 0.8151
# Epoch 48/50
# 169/169 [==============================] - 3s 16ms/step - loss: 0.0836 - accuracy: 0.9605 - val_loss: 0.9572 - val_accuracy: 0.8196
# Epoch 49/50
# 169/169 [==============================] - 3s 16ms/step - loss: 0.0933 - accuracy: 0.9562 - val_loss: 1.0175 - val_accuracy: 0.8181
# Epoch 50/50
# 169/169 [==============================] - 3s 16ms/step - loss: 0.0895 - accuracy: 0.9588 - val_loss: 0.8883 - val_accuracy: 0.8456

# %% [markdown]
# #### Visualize the model results

# %%
# Visualize this model
accuracy_plot(history, epochs)

# %%
# Lets store the final accuracy of model 3 in the accuracy_history_df dataframe
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
accuracy_history_df = accuracy_history_df.append([{"Type":"Model 3 - Class rebalance","Training Accuracy":acc[-1],"Validation Accuracy":val_acc[-1],"Training Loss":loss[-1],"Validation Loss":val_loss[-1],"Epochs":epochs}])
accuracy_history_df
# Out:
#                                       Type  Training Accuracy  \
# 0                Model 1 - Default Vanilla           0.887835
# 0  Model 2 - Extra data augmentation layer           0.592634
# 0                Model 3 - Class rebalance           0.958828
#
#    Validation Accuracy  Training Loss  Validation Loss  Epochs
# 0             0.530201       0.289494         2.436409      20
# 0             0.559284       1.139552         1.333660      20
# 0             0.845583       0.089452         0.888296      50

# %% [markdown]
# <div class="alert alert-info">
# <strong>Observations:</strong>
# <ul>
# <li>Much better model than the previous two models</li>
# <li>The training accuracy seems to be nearly ~95%.</li>
# <li>The validation accuracy is nearly ~84%.</li>
# <li>Class rebalance has helped treating the overfitting and underfitting with respect to Accuracy. However, Validation loss is very high as compared to Training loss. This indicates that overfitting is still there. </li>
# <li>We can try building the models with more epochs and layers.</li>
# </ul>
# </div>
